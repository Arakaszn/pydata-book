# %% [markdown]
# # Section 5.1
#
# ## Problem 1: The "Stock Portfolio" Series
#
# **Goal:** Practice Series creation, indexing, and alignment based on labels.
#
# **The Scenario:**
# You have two dictionaries representing the number of shares owned in different companies across two different brokerage accounts.
#
# 1. **Create two Series** from the following data:
# * `account_A`: `{'AAPL': 10, 'GOOG': 5, 'MSFT': 20}`
# * `account_B`: `{'AAPL': 5, 'TSLA': 10, 'MSFT': 10}`
#
#
# 2. **Calculate the total portfolio:** Create a third Series, `total_portfolio`, by adding `account_A` and `account_B`.
# 3. **Handle the Missing Data:** Notice that some stocks (GOOG, TSLA) appear in one account but not the other, resulting in `NaN` values. Use a pandas method to fill those `NaN` values with `0` so the total reflects the actual shares owned.
# 4. **Filter:** Print only the stocks where you own more than 15 shares total.

# %%
# Type your solution here:

# %% [markdown]
# ## Problem 2: The "Gradebook" DataFrame
#
# **Goal:** Practice DataFrame construction, column selection, and boolean indexing.
#
# **The Scenario:**
# You need to organize student data for a small lab section.
#
# 1. **Construct a DataFrame** named `grades` using a dictionary of lists:
# * `Student`: 'Alice', 'Bob', 'Charlie', 'Dana'
# * `Score`: 85, 72, 91, 60
# * `Attendance`: 90, 80, 95, 70
#
#
# 2. **Add a Column:** Add a new column called `Passed`. This should be a boolean column (`True`/`False`) that is `True` if the `Score` is greater than 70.
# 3. **Reindex/Select:** Create a new DataFrame that only contains the `Student` and `Score` columns, sorted by `Score` in descending order.
# 4. **Specific Selection:** Use the `.iloc` or `.loc` method (as discussed in 5.1) to retrieve the score of the third student (Charlie).

# %%
# Type your solution here:

# %% [markdown]
# # Section 5.2
#
# ## Problem 1: The "Inventory Drift" Challenge
#
# **Goal:** Practice **reindexing** and **arithmetic alignment** with missing values.
#
# Imagine a small tech shop. They have their inventory at the start of the week and a list of items sold. However, the "Sold" list contains some items the shop doesn't carry, and is missing others they do.
#
# **The Setup:**
#
# ```python
# import pandas as pd
# import numpy as np
#
# # Starting inventory
# inventory = pd.Series([20, 15, 30, 10],
#                       index=['Laptops', 'Mice', 'Keyboards', 'Monitors'])
#
# # Sales recorded (note the 'Webcams' entry which isn't in inventory)
# sales = pd.Series([5, 8, 4],
#                   index=['Laptops', 'Keyboards', 'Webcams'])
#
# ```
#
# **The Task:**
#
# 1. Create a new Series called `updated_inventory` by subtracting `sales` from `inventory`.
# 2. Your students will notice `NaN` values. Ask them to use the `.sub()` method with a `fill_value` of 0 so that items not sold remain at their original count.
# 3. **Bonus:** Use `reindex` on the `sales` Series to match the `inventory` index before performing the subtraction. What happens to 'Webcams'?

# %%
# Type your solution here:

# %% [markdown]
# ## Problem 2: The Multi-Axis Selection Puzzle
#
# **Goal:** Master `loc` and `iloc` for **slicing and filtering** DataFrames.
#
# **The Setup:**
#
# ```python
# data = pd.DataFrame(np.arange(16).reshape((4, 4)),
#                     index=['Ohio', 'Colorado', 'Utah', 'New York'],
#                     columns=['one', 'two', 'three', 'four'])
#
# ```
#
# **The Task:**
# Provide the students with three specific targets to extract from this DataFrame:
#
# 1. **The Label Slice:** Select the rows for 'Colorado' and 'Utah' but only for columns 'two' and 'three'.
# 2. **The Hybrid Logic:** Select all rows where the value in column 'three' is greater than 5, and then only show the first two columns of those rows.
# 3. **The Integer Reset:** Using `iloc`, select every other row (Ohio and Utah) and the last two columns.

# %%
# Type your solution here:

# %% [markdown]
# # Section 5.3
#
# ## Problem 1: Analyzing Tech Stock Volatility
#
# This problem tests their ability to handle missing data and find specific "event" dates using index methods.
#
# **The Scenario:** You have a DataFrame representing the daily closing prices of three tech companies. Note that some days are missing data due to exchange holidays or technical glitches.
#
# ```python
# import pandas as pd
# import numpy as np
#
# data = {
#     'Apple': [150, 152, np.nan, 155, 160],
#     'Google': [2800, np.nan, 2810, 2825, 2790],
#     'Microsoft': [300, 305, 310, np.nan, 308]
# }
# df = pd.DataFrame(data, index=['Mon', 'Tue', 'Wed', 'Thu', 'Fri'])
#
# ```
#
# **The Task:**
#
# 1. Calculate the **average price** for each company for the week, ensuring the calculation isn't returned as `NaN` just because one day is missing.
# 2. Find the **specific day** (index label) on which each company reached its highest price.
# 3. Calculate the **cumulative sum** of prices across the week for each company to see the "growth" trend.

# %%
# Type your solution here:

# %% [markdown]
# ## Problem 2: Sensor Data "Drift"
#
# This problem focuses on row-wise vs. column-wise reductions and the behavior of the `level` or `axis` arguments.
#
# **The Scenario:**
# A researcher is monitoring CO2 levels from two different sensors in a lab. They want to compare the sensors and look for anomalies.
#
# ```python
# sensors = pd.DataFrame({
#     'Sensor_A': [400, 402, 401, 405, 450],
#     'Sensor_B': [398, 401, 400, 402, 404]
# }, index=pd.Index(['12:00', '12:05', '12:10', '12:15', '12:20'], name='Time'))
#
# ```
#
# **The Task:**
#
# 1. Find the **summary statistics** (mean, std, min, max) for both sensors simultaneously using a single method from Section 5.3.
# 2. Calculate the **mean CO2 level per time slot** (the average of Sensor A and Sensor B for each row).
# 3. **Critical Thinking:** Based on the results, Sensor A shows a sudden jump at 12:20. Use a method to find the **percentage change** or the **correlation** between the two sensors (if they've read ahead) or simply compare the `idxmax` of both to identify the outlier.

# %%
# Type your solution here:
